# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df.shape
# Out:
# (30, 3)

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
X = df["YearsExperience"]
y = df["Salary"]

# %%
X = X.values
y = y.values

# %%
w = 0
b = 0
lr = 0.01
epochs = 1000
n = len(X)

# %%
for _ in range(epochs):
    y_pred = w * X + b
    loss = np.mean((y - y_pred) ** 2)
    dw = (-2/n) * np.sum(X * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)
    w = w - lr * dw
    b = b - lr * db

# %%
print("Final weight (w):", w)
print("Final bias (b):", b)
print("Final loss:", loss)
# Out:
# Final weight (w): 9504.801321957242
# Final bias (b): 24474.557566113308
# Final loss: 31300502.429962

# %%
w = 0
b = 0
losses = []

for _ in range(epochs):
    y_pred = w * X + b
    loss = np.mean((y - y_pred) ** 2)
    losses.append(loss)
    dw = (-2/n) * np.sum(X * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)
    w -= lr * dw
    b -= lr * db

# %%
import matplotlib.pyplot as plt

plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.show()

# %%
learning_rates = [0.1, 0.01, 0.001]

for lr in learning_rates:
    w = 0
    b = 0
    losses = []

    for _ in range(epochs):
        y_pred = w * X + b
        loss = np.mean((y - y_pred) ** 2)
        losses.append(loss)
        dw = (-2/n) * np.sum(X * (y - y_pred))
        db = (-2/n) * np.sum(y - y_pred)
        w -= lr * dw
        b -= lr * db

    plt.plot(losses, label=f"lr={lr}")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\_methods.py:132: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\hp\AppData\Local\Temp\ipykernel_24036\1447131291.py:10: RuntimeWarning: overflow encountered in square
#   loss = np.mean((y - y_pred) ** 2)
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\hp\AppData\Local\Temp\ipykernel_24036\1447131291.py:14: RuntimeWarning: invalid value encountered in scalar subtract
#   w -= lr * dw

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X.reshape(-1,1), y)

print("sklearn weight:", model.coef_[0])
print("sklearn bias:", model.intercept_)
# Out:
# sklearn weight: 9449.962321455074
# sklearn bias: 24848.203966523208
